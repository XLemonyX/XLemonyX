# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1

# %% [markdown]
# For every column in the data:
#
# State whether the values match the description given in the table above.
#
# State the number of missing values in the column.
#
# Describe what you did to make values match the description if they did not match.
#
# **product_id:** There were 1500 unique values that match the description given. There were no missing values. No changes were made to this column.
#
# **category:**  There were 1475 values that match 6 given in data dictionary. There were 25 values listed as '-', seen as missing vale. All misssing values were replaced with "Unknown".
#
# **animal:** There were 1500 values that match 4 given in data dictionary. There were no missing values. No changes were made to this column.
#
# **size:** There were 1500 values that match 4 given in data dictionary. There were no missing values. Data was untidy and was converted so that all entries were title case.
#
# **price:** There were 1350 unique values that match the description given. There were 150 entries called 'unlisted', which is seen as missing values. All missing values were replaced with overall median price of 28,07. All data was rounded to two decimal places.
#
# **sales:** There were 1500 values that match the description given. There were no missing values. Data was cleaned, all values converted into numbers and rounded to two decimal places.
#
# **rating:** There were 1350 values that match the description given. There were 150 missing values. All missing values were replaced with 0.
#
# **repeat_purchase:** There were 1500 values that match the description given. There were no missing values. No changes were made to this column.

# %% [markdown]
# ## Task 2

# %% [markdown]
# Create a visualization that shows how many products are repeat purchases. Use the visualization to:
#
# State which category of the variable repeat purchases has the most observations
#
# Explain whether the observations are balanced across categories of the variable repeat purchases
#
# ![repeat_purchases](repeat_purchases.PNG)
#
# There are 7 categories of products included in this data. The most common type listed is Equipment having the most observations. Next four categories are balanced and there is very little difference between them. The last two categories being Accessories and Unknown category having the least number of repeat purchases. Understanding which specific equipment products are being resold, will give PetMind a clearer picture of the daily needs of their customers.

# %% [markdown]
# ## Task 3

# %% [markdown]
# Describe the distribution of all of the sales. Your answer must include a visualization that shows the distribution.
#
# ![distribution](distribution.PNG)
#
# Looking at the distribution of sales, we can see from the graph above that the median value for the sales is is around 1000. The distribution of the number of sales is normal. There are some outliers that get more than 2256 sales but this is very uncommon, I would suggest investigate which products fall in the outliers section of the graph, to try and understand why they were sold more than others.

# %% [markdown]
# ## Task 4

# %% [markdown]
# Describe the relationship between repeat purchases and sales. Your answer must include a visualization to demonstrate the relationship.
#
# ![correlation](correlation.PNG)
#
# This scatter plot and Pearson correlation coefficient clearly shows that there is a strong positive correlation between number of sales and repeat purchases. Sales increase with the amount of repeat purchases. We can conclude that companys's approach over the last year contributed to increasing sales of every day products in repeated manner.
